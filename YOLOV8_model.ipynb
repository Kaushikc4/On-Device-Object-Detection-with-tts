# %%
# !pip install ultralytics==8.0.196
# !pip install roboflow

# %%
import os
HOME = os.getcwd()
print(HOME)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from roboflow import Roboflow
rf = Roboflow(api_key="1upftHbAB56X11ZbAv1n")
project = rf.workspace("jacob-solawetz").project("pascal-voc-2012")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# import shutil
# shutil.move('/content/Pascal-VOC-2012-1', '/content/drive/MyDrive/Dataset1')

# %%
# Verify the upload
#!ls '/content/drive/MyDrive/Dataset1/valid/images/'

# %%
# !nvidia-smi

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import os
HOME = os.getcwd()
print(HOME)

# %%
dataset.location

# %%
#dataset="/content/drive/MyDrive/Dataset1"

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 plots=True

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml

# %%
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("best.pt")

# Export the model to TFLite format
model.export(format="tflite")  # creates 'yolov8n_float32.tflite'

# Load the exported TFLite model
tflite_model = YOLO("/content/best_saved_model/best_float32.tflite")
